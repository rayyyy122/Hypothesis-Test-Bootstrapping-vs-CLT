# %% [markdown]
# # STAT 201 Proposal

# %% [markdown]
# ## Group 11

# %% [markdown]
# # Compare the delay rate of two populer airlines in the United States

# %% [markdown]
# ## Introduction

# %% [markdown]
# The demand for travelling by air has been increassing rapidly over the years. The average delay rate of an airline has become a essential standard for customers to evaluate and choose a company. In this dataset, 18 airlines in the U.S.

# %% [markdown]
# ## Preliminary Result

# %%
library(tidyverse)
library(infer)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
airlines_delay <- read.csv("airlines_delay.csv", header = TRUE)

head(airlines_delay)
# Out:
#   Flight Time Length Airline AirportFrom AirportTo DayOfWeek Class
# 1 2313   1296 141    DL      ATL         HOU       1         0
# 2 6948    360 146    OO      COS         ORD       4         0
# 3 1247   1170 143    B6      BOS         CLT       3         0
# 4   31   1410 344    US      OGG         PHX       6         0
# 5  563    692  98    FL      BMI         ATL       4         0
# 6 3692    580  60    WN      MSY         BHM       4         0

# %%
delay_data <- airlines_delay |> 
    filter(Airline %in% c("DL", "AA")) |> 
    rename(Delay = Class) |>
    filter(!is.na(Airline)) |> 
    filter(!is.na(Delay)) |>
    mutate(Delay = as.factor(Delay))

head(delay_data)
# Out:
#   Flight Time Length Airline AirportFrom AirportTo DayOfWeek Delay
# 1 2313   1296 141    DL      ATL         HOU       1         0
# 2 1300   1210  80    AA      DFW         MEM       3         0
# 3 1578    740 120    DL      EYW         ATL       1         0
# 4 1698    330  77    DL      JAX         ATL       4         0
# 5 2744    715 219    DL      SAN         MSP       3         0
# 6 2722     30 228    DL      PHX         DTW       1         0

# %%
plot <- delay_data |> 
    ggplot(aes(x = Airline, fill = Delay)) +
    geom_bar(width = 0.5) + 
    ylab("the number of flights")

plot
# Out:
# plot without title

# %% [markdown]
# ## Methods

# %% [markdown]
# In this project, we plan to use two different methods to conduct a hypothesis test about the proportion of delayed flights operated by Delta Airlines and Amenrican Airline. First we will use bootstarpping method in the infer package and then we plan to use theory based approach to perform a hypothesis test.

# %% [markdown]
# ## Reference
